# %% [markdown]
# # Python Basic - Assignment 4
# ---

# %% [markdown]
# #### 1. What does an empty dictionary's code look like?

# %%
a = {}
type(a)
# Out:
# dict

# %% [markdown]
# #### 2. What is the value of a dictionary value with the key 'foo' and the value 42?

# %%
# The key is 'food' and value is 42
dictionary = {"foo":42}
dictionary['foo']
# Out:
# 42

# %% [markdown]
# #### 3. What is the most significant distinction between a dictionary and a list?

# %%
# List has sequence of objetcs and the elements are accessed by their position
# Dictionary are key-value pairs and the elements are accessed by the key name

# %% [markdown]
# #### 4. What happens if you try to access spam['foo'] if spam is {'bar': 100}?

# %%
spam = {'bar': 100}
span['foo']
# It throws an error because the dictonary has no key by name "foo"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-f4a7dedfa0d7> in <module>
#       1 spam = {'bar': 100}
# ----> 2 span['foo']
#       3 # It throws an error because the dictonary has no key by name "foo"
#
# NameError: name 'span' is not defined

# %% [markdown]
# #### 5. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.keys()?

# %%
spam = {'cat': 10}

# The 'cat' in spam will look for any keys with the name 'cat'.
"cat" in spam
# Out:
# True

# %%
# The 'cat' in spam will look for "cat" in list of key values generated by spam.keys()
'cat' in spam.keys()
# Out:
# True

# %% [markdown]
# #### 6. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.values()?

# %%
# The 'cat' in spam will look for any keys with the name 'cat'
"cat" in spam
# Out:
# True

# %%
# 'cat' in spam.values() will looks for 'cat' in list of values of dictionary. Hence, will return False
'cat' in spam.values()
# Out:
# False

# %% [markdown]
# #### 7. What is a shortcut for the following code?
# #### if 'color' not in spam:
# #### spam['color'] = 'black'

# %%
spam = {}
spam['color'] = 'black'

# %% [markdown]
# #### 8. How do you "pretty print" dictionary values using which module and function?

# %%
# Module - pprint
from pprint import pprint
my_collection = {'car':{"name":"Tiguan","company":"VW","seating_capacity":"7"},
                'laptop': {'name':'rog','compamy':'asus','ram':"16GB"}}
print(my_collection)
print("########################################")
pprint(my_collection)
# Out:
# {'car': {'name': 'Tiguan', 'company': 'VW', 'seating_capacity': '7'}, 'laptop': {'name': 'rog', 'compamy': 'asus', 'ram': '16GB'}}
# ########################################
# {'car': {'company': 'VW', 'name': 'Tiguan', 'seating_capacity': '7'},
#  'laptop': {'compamy': 'asus', 'name': 'rog', 'ram': '16GB'}}
